# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -q opencv-python-headless scikit-learn tensorflow matplotlib seaborn joblib optuna statsmodels scipy

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/0research/battery-thermal-anomaly/src')

from pipeline import run
results = run()

# %%
# Access results directly
# results['df_fused']     — full annotated DataFrame
# results['summary_df']   — method comparison table
# results['crate_df']     — per C-rate metrics
# results['diff_df']      — feature differences
# results['separability'] — GMM separability score
print(results['summary_df'])
